# %%
x = 39
y = 46
print(x*y+y)
# Out:
# 1840

# %%
orig_list = [9,9,9,2]
labels = ['a','b','c','d']
squares = {labels[ i ]: orig_list[ i ] * orig_list[ i ] for i in range(len(labels))}
print(squares[ labels[ 3 ] ])
# Out:
# 4

# %%
map(lambda x: x%2 == 0, the_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 map(lambda x: x%2 == 0, the_list)
#
# NameError: name 'the_list' is not defined
